# %%
from bs4 import BeautifulSoup
import urllib.request
import json

# %%
def get_soup(url):
    
    headers = headers={
        'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/70.0.3538.77 Safari/537.36'
    }

    req = urllib.request.Request(f"{url}", headers=headers)
    with urllib.request.urlopen(req) as response:
        html = response.read()
        return BeautifulSoup(html, 'html.parser')
    
def get_gamecast_urls(date):
    scoreboard_url = "http://www.espn.com/nba/scoreboard"
    
    soup = get_soup(scoreboard_url)
    
    js = ""
    for s in soup.find_all("script"):
        txt = s.get_text()

        if "window.espn.scoreboardData" not in txt:
            continue

        end = txt.index(";window.espn.scoreboardSettings")
        start = txt.index("= {")

        js = txt[start+2:end]

        break
        
    loaded = json.loads(js)
    
    print(loaded)
    
    links = []
    
    for e in loaded["events"]:
        for c in e["competitions"]:
            for o in c["odds"]:
                print(o["details"])
    
    return links

def get_line_info(gamecast_url):
    soup = get_soup(gamecast_url)
    
    mydivs = soup.findAll("div", {"class": "odds-details"})
    
    arr = mydivs[0].findAll("li")[0].get_text().replace("Line: ", "").split(' ')

    team = arr[0].lower()
    spread = arr[1]
    
    return (team, spread)

# %%
urls = get_gamecast_urls("bla")
# Out:
# {'leagues': [{'calendarIsWhitelist': False, 'calendar': ['2018-09-13T07:00Z', '2018-09-14T07:00Z', '2018-09-15T07:00Z', '2018-09-16T07:00Z', '2018-09-17T07:00Z', '2018-09-18T07:00Z', '2018-09-19T07:00Z', '2018-09-20T07:00Z', '2018-09-21T07:00Z', '2018-09-22T07:00Z', '2018-09-23T07:00Z', '2018-09-24T07:00Z', '2018-09-25T07:00Z', '2018-09-26T07:00Z', '2018-09-27T07:00Z', '2018-10-13T07:00Z', '2018-10-14T07:00Z', '2018-10-15T07:00Z', '2018-11-22T08:00Z', '2018-12-24T08:00Z', '2019-02-16T08:00Z', '2019-02-18T08:00Z', '2019-02-19T08:00Z', '2019-02-20T08:00Z', '2019-04-08T07:00Z', '2019-04-11T07:00Z', '2019-04-12T07:00Z', '2019-04-13T07:00Z', '2019-04-14T07:00Z', '2019-04-15T07:00Z', '2019-04-16T07:00Z', '2019-04-17T07:00Z', '2019-04-18T07:00Z', '2019-04-19T07:00Z', '2019-04-20T07:00Z', '2019-04-21T07:00Z', '2019-04-22T07:00Z', '2019-04-23T07:00Z', '2019-04-24T07:00Z', '2019-04-25T07:00Z', '2019-04-26T07:00Z', '2019-04-27T07:00Z', '2019-04-28T07:00Z', '2019-04-29T07:00Z', '2019-04-30T07:00Z', '2019-05-01T07:00Z', '2019-05-02T07:00Z', '2019-05-03T07:00Z', '2019-05-04T07:00Z', '2019-05-05T07:00Z', '2019-05-06T07:00Z', '2019-05-07T07:00Z', '2019-05-08T07:00Z', '2019-05-09T07:00Z', '2019-05-10T07:00Z', '2019-05-11T07:00Z', '2019-05-12T07:00Z', '2019-05-13T07:00Z', '2019-05-14T07:00Z', '2019-05-15T07:00Z', '2019-05-16T07:00Z', '2019-05-17T07:00Z', '2019-05-18T07:00Z', '2019-05-19T07:00Z', '2019-05-20T07:00Z', '2019-05-21T07:00Z', '2019-05-22T07:00Z', '2019-05-23T07:00Z', '2019-05-24T07:00Z', '2019-05-25T07:00Z', '2019-05-26T07:00Z', '2019-05-27T07:00Z', '2019-05-28T07:00Z', '2019-05-29T07:00Z', '2019-05-30T07:00Z', '2019-05-31T07:00Z', '2019-06-01T07:00Z', '2019-06-02T07:00Z', '2019-06-03T07:00Z', '2019-06-04T07:00Z', '2019-06-05T07:00Z', '2019-06-06T07:00Z', '2019-06-07T07:00Z', '2019-06-08T07:00Z', '2019-06-09T07:00Z', '2019-06-10T07:00Z', '2019-06-11T07:00Z', '2019-06-12T07:00Z', '2019-06-13T07:00Z', '2019-06-14T07:00Z', '2019-06-15T07:00Z', '2019-06-16T07:00Z', '2019-06-17T07:00Z', '2019-06-18T07:00Z', '2019-06-19T07:00Z', '2019-06-20T07:00Z', '2019-06-21T07:00Z', '2019-06-22T07:00Z', '2019-06-23T07:00Z'], 'uid': 's:40~l:46', 'calendarType': 'day', 'calendarEndDate': '2019-06-24T06:59Z', 'calendarStartDate': '2018-09-13T07:00Z', 'name': 'National Basketball Association', 'season': {'year': 2019, 'endDate': '2019-06-24T06:59Z', 'type': {'name': 'Regular Season', 'id': '2', 'type': 2, 'abbreviation': 'reg'}, 'startDate': '2018-09-13T07:00Z'}, 'id': '46', 'abbreviation': 'NBA', 'slug': 'nba'}], 'season': {'year': 2019, 'type': 2}, 'day': {'date': '2018-12-23'}, 'events': [{'date': '2018-12-23T21:00Z', 'uid': 's:40~l:46~e:401071167', 'name': 'Atlanta Hawks at Detroit Pistons', 'competitions': [{'date': '2018-12-23T21:00Z', 'venue': {'address': {'city': 'Detroit', 'state': 'MI'}, 'fullName': 'Little Caesars Arena', 'indoor': True, 'id': '5404', 'capacity': 21000}, 'conferenceCompetition': False, 'notes': [], 'tickets': [{'summary': '1,610 tickets as low as $14', 'numberAvailable': 1610, 'links': [{'href': 'https://www.vividseats.com/nba-basketball/detroit-pistons-tickets/pistons-12-23-2805362.html?wsUser=717'}, {'href': 'https://www.vividseats.com/venues/little-caesars-arena-tickets.html?wsUser=717'}]}], 'timeValid': True, 'geoBroadcasts': [{'market': {'id': '2', 'type': 'Home'}, 'media': {'shortName': 'FSDT'}, 'type': {'id': '1', 'shortName': 'TV'}, 'lang': 'en', 'region': 'us'}], 'broadcasts': [{'market': 'home', 'names': ['FSDT']}], 'uid': 's:40~l:46~e:401071167~c:401071167', 'competitors': [{'uid': 's:40~l:46~t:8', 'homeAway': 'home', 'score': '0', 'records': [{'summary': '15-15', 'name': 'Total', 'abbreviation': 'Total', 'type': 'total'}, {'summary': '10-7', 'name': 'Home', 'type': 'home'}, {'summary': '5-8', 'name': 'Road', 'type': 'road'}], 'leaders': [{'shortDisplayName': 'PPG', 'displayName': 'Points Per Game', 'name': 'pointsPerGame', 'leaders': [{'displayValue': '25.6', 'athlete': {'displayName': 'Blake Griffin', 'jersey': '23' ...
# DET -9.5
# IND -10.5
# BOS -7.0
# BKN -9.5
# CLE -1.0
# ORL -2.5
# NO -1.5
# OKC -7.0
# GS -10.5
# POR -8.0
# LAL -5.5

# %%
for u in urls:
    print(get_line_info(u))
# Out:
# ('bos', '-12.0')
# ('cha', '-10.0')
# ('bkn', '-3.0')
# ('mil', '-9.5')
# ('phi', '-3.0')
# ('mem', '-4.0')
# ('okc', '-2.0')
# ('tor', '-1.5')
# ('gs', '-7.0')

# %%
for e in loaded["events"]:
    print(list(e.keys()))
    print(e["shortName"])
    break
# Out:
# ['date', 'uid', 'name', 'competitions', 'season', 'links', 'id', 'shortName', 'status']
# ATL @ BOS
